# %%
import frequency_analysis
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
frequency_analysis.load()

# %%
frequency_analysis.plot_raw_data()

# %%
frequency_analysis.plot_frequency_vs_lat()

# %%
frequency_analysis.plot_frequency_vs_speed()
